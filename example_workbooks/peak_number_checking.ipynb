CV-50_1.wiff.dia.extracted.txt', '20210702_Kuebler_11_P1_D8_HD-4B_1.wiff.dia.extracted.txt', '20210702_Kuebler_24_P1_H2_CV-62_1.wiff.dia.extracted.txt', '20210702_Kuebler_50_P1_A7_CV-19D_1.wiff.dia.extracted.txt', '20210702_Kuebler_17_P1_F8_Plasma-09_1.wiff.dia.extracted.txt', '20210702_Kuebler_12_P1_G8_CV-1_1.wiff.dia.extracted.txt', '20210702_Kuebler_2_P2_B1_PlasmaPooled_1.wiff.dia.extracted.txt', '20210702_Kuebler_36_P1_H1_HD-3C_1.wiff.dia.extracted.txt', '20210702_Kuebler_18_P1_C4_CV-63_1.wiff.dia.extracted.txt', '20210702_Kuebler_30_P1_B4_CV-8_1.wiff.dia.extracted.txt', '20210702_Kuebler_6_P1_E8_CV-32_1.wiff.dia.extracted.txt', '20210702_Kuebler_7_P1_B6_HD-9_1.wiff.dia.extracted.txt', '20210702_Kuebler_52_P1_A3_CV-57_1.wiff.dia.extracted.txt', '20210702_Kuebler_53_P1_A4_HD-5_1.wiff.dia.extracted.txt', '20210702_Kuebler_41_P1_H4_CV-56_1.wiff.dia.extracted.txt', '20210702_Kuebler_47_P1_F7_CV-33_1.wiff.dia.extracted.txt', '20210702_Kuebler_4_P1_E7_CV-58_1.wiff.dia.extracted.txt', '20210702_Kuebler_51_P1_B3_HD-12_1.wiff.dia.extracted.txt'])
# ['138.055', '186.076', '204.087', '274.092', '292.103', '366.14', '657.235']

# %% [markdown]
# Bin the spectra to make them easier to work with and merge

# %%
rt_x_bin_size = 0.025
mz_y_bin_size = 2.0

binned_spectra = {
    name: glycoproteomics.spectrum.bin(
        spectrum,
        rt_x_bin_size,
        mz_y_bin_size,
        np.mean
    ) for name, spectrum in spectra.items()
}
del(spectra)

# %%
merged_ion_matrix, x_label, y_label = glycoproteomics.spectrum.to_matrix(
    binned_spectra[ref_spectrum_name],
    ref_ions
)
glycoproteomics.plotting.plot_ion_matrix(
    merged_ion_matrix,
    x_label,
    y_label,
    ref_spectrum_name,
    figure_size,
    dpi
)
plt.show()

# %%
min_rt = 5.0
max_rt = 23.0

filtered_binned_spectra = {
    name: glycoproteomics.spectrum.filter_rt(
        binned_spectrum,
        min_rt,
        max_rt
    ) for name, binned_spectrum in binned_spectra.items()
}
del(binned_spectra)

merged_ion_matrix, x_label, y_label = glycoproteomics.spectrum.to_matrix(
    filtered_binned_spectra[ref_spectrum_name],
    ref_ions
)
glycoproteomics.plotting.plot_ion_matrix(
    merged_ion_matrix,
    x_label,
    y_label,
    ref_spectrum_name,
    figure_size,
    dpi
)
plt.show()

# %%
top_N_peaks = 10000

quantify_x_radius = rt_x_bin_size * 3.0
quantify_y_radius = mz_y_bin_size * 5.0

exclusion_x_radius = quantify_x_radius * 3.0
exclusion_y_radius = quantify_y_radius * 3.0

peaks = glycoproteomics.peaks.find(
    merged_ion_matrix,
    x_label,
    y_label,
    top_N_peaks,
    exclusion_x_radius,
    exclusion_y_radius
)

glycoproteomics.plotting.plot_ion_matrix_with_peaks(
    merged_ion_matrix,
    x_label,
    y_label,
    peaks,
    exclusion_x_radius,
    exclusion_y_radius,
    ref_spectrum_name + " - Top {} peaks".format(len(peaks)),
    figure_size,
    dpi
)
plt.show()

glycoproteomics.plotting.plot_ion_matrix_with_peaks(
    merged_ion_matrix,
    x_label,
    y_label,
    peaks,
    quantify_x_radius,
    quantify_y_radius,
    ref_spectrum_name + " - Quantification regions",
    figure_size,
    dpi
)
plt.show()

# %%
for name, spectrum in filtered_binned_spectra.items():
    merged_ion_matrix, x_label, y_label = glycoproteomics.spectrum.to_matrix(
        spectrum,
        ref_ions
    )
    peaks = glycoproteomics.peaks.find(
        merged_ion_matrix,
        x_label,
        y_label,
        top_N_peaks,
        exclusion_x_radius,
        exclusion_y_radius
    )
    print("{}: {}".format(name, len(peaks)))
# Out:
# 20210702_Kuebler_54_P1_A8_HD-7_1.wiff.dia.extracted.txt: 1018
# 20210702_Kuebler_26_P1_A1_CV-24C_1.wiff.dia.extracted.txt: 987
# 20210702_Kuebler_56_P2_B1_PlasmaPooled_4.wiff.dia.extracted.txt: 1019
# 20210702_Kuebler_25_P1_G7_CV-64_1.wiff.dia.extracted.txt: 1007
# 20210702_Kuebler_29_P1_G4_CV-13_1.wiff.dia.extracted.txt: 981
# 20210702_Kuebler_38_P2_B1_PlasmaPooled_3.wiff.dia.extracted.txt: 1003
# 20210702_Kuebler_22_P1_D7_CV-48_1.wiff.dia.extracted.txt: 996
# 20210702_Kuebler_16_P1_H3_CV-16_1.wiff.dia.extracted.txt: 1002
# 20210702_Kuebler_34_P1_C3_CV-9_1.wiff.dia.extracted.txt: 993
# 20210702_Kuebler_40_P1_H6_CV-35_1.wiff.dia.extracted.txt: 994
# 20210702_Kuebler_39_P1_H8_HD-6_1.wiff.dia.extracted.txt: 1003
# 20210702_Kuebler_9_P1_H5_CV-37_1.wiff.dia.extracted.txt: 1002
# 20210702_Kuebler_33_P1_C1_Plasma-11_1.wiff.dia.extracted.txt: 1003
# 20210702_Kuebler_3_P1_G1_HD-1B_1.wiff.dia.extracted.txt: 1003
# 20210702_Kuebler_43_P1_B7_CV-38_1.wiff.dia.extracted.txt: 977
# 20210702_Kuebler_8_P1_F2_CV-25_1.wiff.dia.extracted.txt: 1012
# 20210702_Kuebler_20_P2_B1_PlasmaPooled_2.wiff.dia.extracted.txt: 1006
# 20210702_Kuebler_31_P1_G6_Plasma-02_1.wiff.dia.extracted.txt: 1024
# 20210702_Kuebler_49_P1_C8_HD-15_1.wiff.dia.extracted.txt: 1006
# 20210702_Kuebler_32_P1_C2_CV-61_1.wiff.dia.extracted.txt: 995
# 20210702_Kuebler_45_P1_F4_HD-10_1.wiff.dia.extracted.txt: 992
# 20210702_Kuebler_14_P1_E4_CV-49_1.wiff.dia.extracted.txt: 1024
# 20210702_Kuebler_23_P1_F6_CV-59_1.wiff.dia.extracted.txt: 1006
# 20210702_Kuebler_15_P1_D1_HD-11_1.wiff.dia.extracted.txt: 994
# 20210702_Kuebler_13_P1_B8_CV-75_1.wiff.dia.extracted.txt: 1015
# 20210702_Kuebler_46_P1_D2_CV-60_1.wiff.dia.extracted.txt: 963
# 20210702_Kuebler_48_P1_G2_HD-13_1.wiff.dia.extracted.txt: 977
# 20210702_Kuebler_35_P1_F3_CV-66_1.wiff.dia.extracted.txt: 999
# 20210702_Kuebler_27_P1_F5_CV-23_1.wiff.dia.extracted.txt: 998
# 20210702_Kuebler_21_P1_E5_HD-14_1.wiff.dia.extracted.txt: 989
# 20210702_Kuebler_5_P1_D4_HD-8_1.wiff.dia.extracted.txt: 1017
# 20210702_Kuebler_44_P1_C5_CV-11F_1.wiff.dia.extracted.txt: 1023
# 20210702_Kuebler_28_P1_D3_HD-2B_1.wiff.dia.extracted.txt: 1005
# 20210702_Kuebler_42_P1_B2_CV-65_1.wiff.dia.extracted.txt: 990
# 20210702_Kuebler_10_P1_E6_CV-50_1.wiff.dia.extracted.txt: 1013
# 20210702_Kuebler_11_P1_D8_HD-4B_1.wiff.dia.extracted.txt: 1009
# 20210702_Kuebler_24_P1_H2_CV-62_1.wiff.dia.extracted.txt: 1002
# 20210702_Kuebler_50_P1_A7_CV-19D_1.wiff.dia.extracted.txt: 990
# 20210702_Kuebler_17_P1_F8_Plasma-09_1.wiff.dia.extracted.txt: 1002
# 20210702_Kuebler_12_P1_G8_CV-1_1.wiff.dia.extracted.txt: 989
# 20210702_Kuebler_2_P2_B1_PlasmaPooled_1.wiff.dia.extracted.txt: 1000
# 20210702_Kuebler_36_P1_H1_HD-3C_1.wiff.dia.extracted.txt: 993
# 20210702_Kuebler_18_P1_C4_CV-63_1.wiff.dia.extracted.txt: 1001
# 20210702_Kuebler_30_P1_B4_CV-8_1.wiff.dia.extracted.txt: 979
# 20210702_Kuebler_6_P1_E8_CV-32_1.wiff.dia.extracted.txt: 1003
# 20210702_Kuebler_7_P1_B6_HD-9_1.wiff.dia.extracted.txt: 998
# 20210702_Kuebler_52_P1_A3_CV-57_1.wiff.dia.extracted.txt: 997
# 20210702_Kuebler_53_P1_A4_HD-5_1.wiff.dia.extracted.txt: 1010
# 20210702_Kuebler_41_P1_H4_CV-56_1.wiff.dia.extracted.txt: 1011
# 20210702_Kuebler_47_P1_F7_CV-33_1.wiff.dia.extracted.txt: 988
# 20210702_Kuebler_4_P1_E7_CV-58_1.wiff.dia.extracted.txt: 1017
# 20210702_Kuebler_51_P1_B3_HD-12_1.wiff.dia.extracted.txt: 998

# %%
filtered_binned_aligned_sample_spectra = {}
rt_alignment_mappings = {}
for name, spectra in filtered_binned_spectra.items():
    aligned_spectra, rt_alignment = glycoproteomics.spectrum.align_rt(
        spectra,
        filtered_binned_spectra[ref_spectrum_name],
        1,
        False
    )
    filtered_binned_aligned_sample_spectra[name] = aligned_spectra
    rt_alignment_mappings[name] = rt_alignment

merged_spectrum = glycoproteomics.spectrum.combine(
    filtered_binned_aligned_sample_spectra,
    np.sum
)
merged_ion_matrix, x_label, y_label = glycoproteomics.spectrum.to_matrix(
    merged_spectrum,
    ref_ions
)
glycoproteomics.plotting.plot_ion_matrix(
    merged_ion_matrix,
    x_label,
    y_label,
    "Aligned - Merged",
    figure_size,
    dpi
)
plt.show()

# %%
peaks = glycoproteomics.peaks.find(
    merged_ion_matrix,
    x_label,
    y_label,
    top_N_peaks,
    exclusion_x_radius,
    exclusion_y_radius
)

glycoproteomics.plotting.plot_ion_matrix_with_peaks(
    merged_ion_matrix,
    x_label,
    y_label,
    peaks,
    exclusion_x_radius,
    exclusion_y_radius,
    "Aligned - Merged - Top {} peaks".format(len(peaks)),
    figure_size,
    dpi
)
plt.show()

glycoproteomics.plotting.plot_ion_matrix_with_peaks(
    merged_ion_matrix,
    x_label,
    y_label,
    peaks,
    quantify_x_radius,
    quantify_y_radius,
    "Aligned - Merged - Quantification regions",
    figure_size,
    dpi
)
plt.show()
